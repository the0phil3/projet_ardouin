# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from transformers import BertTokenizer
from ML import prep_data
# Out:
# 2023-01-19 13:38:34.910687: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
model = tf.keras.models.load_model('/Users/Theo/Desktop/categorie_model_v.1/')
# Out:
# 2023-01-19 13:38:39.927610: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = pd.read_csv('onglet1.tsv', sep='\t')
data = data.sample(frac=1).reset_index(drop=True)
data
# Out:
#                           unittitle
# 0                            Agenda
# 1       Percies, madame et sa fille
# 2                  Guillard, Gilles
# 3                       Pineau, Dom
# 4          Puymuré, Mademoiselle de
# ...                             ...
# 12471                     Jacquault
# 12472                Gaillart, Roch
# 12473      Saccardy (alias Sacardy)
# 12474  Tronchot (alias Du Tronchot)
# 12475              Desguignardières
#
# [12476 rows x 1 columns]

# %%
data['prep'] = data['unittitle'].apply(prep_data)

# %%
data
# Out:
#                           unittitle  \
# 0                            Agenda
# 1       Percies, madame et sa fille
# 2                  Guillard, Gilles
# 3                       Pineau, Dom
# 4          Puymuré, Mademoiselle de
# ...                             ...
# 12471                     Jacquault
# 12472                Gaillart, Roch
# 12473      Saccardy (alias Sacardy)
# 12474  Tronchot (alias Du Tronchot)
# 12475              Desguignardières
#
#                                                     prep
# 0      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 1      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 2      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 3      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 4      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# ...                                                  ...
# 12471  {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 12472  {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# ...

# %%
data['pred'] = data['prep'].apply(model.predict)
# Out:
# ...
# 1/1 [==============================] - 0s 91ms/step
# ...
# ...
# 1/1 [==============================] - 0s 95ms/step

# %%
data
# Out:
#                           unittitle  \
# 0                            Agenda
# 1       Percies, madame et sa fille
# 2                  Guillard, Gilles
# 3                       Pineau, Dom
# 4          Puymuré, Mademoiselle de
# ...                             ...
# 12471                     Jacquault
# 12472                Gaillart, Roch
# 12473      Saccardy (alias Sacardy)
# 12474  Tronchot (alias Du Tronchot)
# 12475              Desguignardières
#
#                                                     prep  \
# 0      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 1      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 2      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 3      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 4      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# ...                                                  ...
# 12471  {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 12472  {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# ...

# %%
data['result'] = data['pred'].apply(np.argmax)

# %%
data
# Out:
#                           unittitle  \
# 0                            Agenda
# 1       Percies, madame et sa fille
# 2                  Guillard, Gilles
# 3                       Pineau, Dom
# 4          Puymuré, Mademoiselle de
# ...                             ...
# 12471                     Jacquault
# 12472                Gaillart, Roch
# 12473      Saccardy (alias Sacardy)
# 12474  Tronchot (alias Du Tronchot)
# 12475              Desguignardières
#
#                                                     prep  \
# 0      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 1      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 2      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 3      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 4      {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# ...                                                  ...
# 12471  {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# 12472  {'input_ids': ((tf.Tensor(101.0, shape=(), dty...
# ...

# %%
data.to_csv('predicted_data.tsv', sep='\t', index=False)

# %%
sns.histplot(data['result'], bins=10)
# Out:
# <AxesSubplot:xlabel='result', ylabel='Count'>

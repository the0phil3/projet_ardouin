# %%
from functions import *

# %%
master = pd.read_csv('~/dev/projet_ardouin/xl2sqlite/output/master_table.csv', header=0)
total = pd.read_excel('~/dev/projet_ardouin/sources_excel/Ardouin en 1 onglet.xls', header=0)

# %%
Totalclean(total)
# Out:
#        page                 unittitle  \
# 0        89                  Argenton
# 1        90                    Arnoul
# 2        91        Banville, Sieur de
# 3        92  Baroire, le président de
# 4        94     Baugier, Edmé-Antoine
# ...     ...                       ...
# 43281   215              Vivier Paul
# 43282   215               Vogt Martin
# 43283   250     Volage, la frégate la
# 43284   216         Weltmuller, André
# 43285   216      Zimmerman Bolloramus
#
#                                                  contenu  tome   f1   f2   f3  \
# 0                               Ecrivain de la corderie.     1    0  NaN  NaN
# 1                                Doit venir à Rochefort.     1   22  NaN  NaN
# 2      En septembre 1673 il commande l'Hirondelle et ...     1    0  NaN  NaN
# 3      Administre les biens de sa nièce absente, se p...     1    0  NaN  NaN
# 4      Fut fermier général en 1692. Munistionnaire, f...     1   62  NaN  NaN
# ...

# %%
total = total.merge(master,how= 'inner', on = "unittitle")

# %%
ContenuID(total)
# Out:
#        page              unittitle  \
# 0        89               Argenton
# 1         3               Argenton
# 2         3               Argenton
# 3         3               Argenton
# 4         3               Argenton
# ...     ...                    ...
# 36770   215           Vivier Paul
# 36771   215            Vogt Martin
# 36772   250  Volage, la frégate la
# 36773   216      Weltmuller, André
# 36774   216   Zimmerman Bolloramus
#
#                                                  contenu  tome   f1   f2   f3  \
# 0                               Ecrivain de la corderie.     1    0  NaN  NaN
# 1      Ecrivain entretenu ayant l'inspection de la Co...     3  477  621  713
# 2      Aura la place de garde magasin du port vacante...     3   68  187  NaN
# 3                                          Son logement.     3  191  399  451
# 4                                          Son logement.     3  121  296  312
# ...

# %%
Archive_concat(total)
# Out:
# /Users/Theo/dev/projet_ardouin/xl2sqlite/functions.py:97: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dataframe = dataframe.drop(dataframe.columns.difference(['unittitle','dateD', 'dateF','f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10','f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20',
#                    unittitle   f1   f2   f3   f4   f5   f6   f7   f8  f9  ...  \
# 0                   Argenton    0  NaN  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
# 1                   Argenton  477  621  713  NaN  NaN  NaN  NaN  NaN NaN  ...
# 2                   Argenton   68  187  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
# 3                   Argenton  191  399  451  NaN  NaN  NaN  NaN  NaN NaN  ...
# 4                   Argenton  121  296  312  NaN  NaN  NaN  NaN  NaN NaN  ...
# ...                      ...  ...  ...  ...  ...  ...  ...  ...  ...  ..  ...
# ...

# %%
ArchivesID(total)
# Out:
#                    unittitle   f1   f2   f3   f4   f5   f6   f7   f8  f9  ...  \
# 0                   Argenton    0  NaN  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
# 1                   Argenton  477  621  713  NaN  NaN  NaN  NaN  NaN NaN  ...
# 2                   Argenton   68  187  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
# 3                   Argenton  191  399  451  NaN  NaN  NaN  NaN  NaN NaN  ...
# 4                   Argenton  121  296  312  NaN  NaN  NaN  NaN  NaN NaN  ...
# ...                      ...  ...  ...  ...  ...  ...  ...  ...  ...  ..  ...
# 36770           Vivier Paul   306  NaN  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
# 36771            Vogt Martin  203  NaN  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
# 36772  Volage, la frégate la  287  373  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
# 36773      Weltmuller, André  203  NaN  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
# 36774   Zimmerman Bolloramus  203  NaN  NaN  NaN  NaN  NaN  NaN  NaN NaN  ...
#
# ...

# %%
total.to_csv('/Users/Theo/dev/projet_ardouin/xl2sqlite/output/archives_table.csv', index=False)

# %%
total.to_excel('/Users/Theo/dev/projet_ardouin/xl2sqlite/output/archives_table.xlsx', index=False)

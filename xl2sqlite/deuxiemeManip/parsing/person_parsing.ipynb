# %%
from Stanza_Parsing import *
# Out:
# 2023-01-22 17:47:53 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2023-01-22 17:47:53 WARNING: Language fr package default expects mwt, which has been added
# 2023-01-22 17:47:54 INFO: Loading these models for language: fr (French):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | ner       | wikiner |
# ...
#
# 2023-01-22 17:47:54 INFO: Use device: cpu
# 2023-01-22 17:47:54 INFO: Loading: tokenize
# 2023-01-22 17:47:54 INFO: Loading: mwt
# 2023-01-22 17:47:54 INFO: Loading: ner
# 2023-01-22 17:47:56 INFO: Done loading processors!

# %%
total = pd.read_csv('final.tsv', sep='\t')
total.shape
# Out:
# /var/folders/41/1r7_f1_93g56d738vfqw0y8m0000gn/T/ipykernel_9488/2296796038.py:1: DtypeWarning: Columns (9,10,11,17,18,24,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   total = pd.read_csv('final.tsv', sep='\t')
# (43267, 40)

# %%
total.drop(total.columns.difference(['unittitle', 'contenu','page', 'tome', 'ID', 'cID']), 1, inplace=True)
total = total.drop_duplicates(subset=['cID'], keep='first')  
total.dropna(subset=['contenu'], inplace=True)
total.shape
# Out:
# /var/folders/41/1r7_f1_93g56d738vfqw0y8m0000gn/T/ipykernel_9488/1987920939.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   total.drop(total.columns.difference(['unittitle', 'contenu','page', 'tome', 'ID', 'cID']), 1, inplace=True)
# (38780, 6)

# %%
sample = total.sample(n=100)
sample
# Out:
#        page                  unittitle  \
# 14350    63                      Féret
# 34013   217  Fulminant, le vaisseau le
# 1580    141                    Massiot
# 23402   122             Lamorlière, de
# 12155    38                    Dalesme
# ...     ...                        ...
# 16105    17                     Bénard
# 32652   231    Renommée, la frégate la
# 26783   153         Mesnard du Plessis
# 14594   155                      Véron
# 7260     29                  Carmeline
#
#                                                  contenu  tome      ID     cID
# 14350  Arrêté. Le prévôt de la Marine instruira son p...     3   P4471  C16651
# 34013                                       Le radouber.     2    B238  C16613
# 1580                          Commissaire à La Rochelle.     2   P7462  C27116
# 23402  cadet dans les troupes de Cayenne, sera passag...     8   P6171  C22536
# 12155  Offre de venir à Rochefort pour donner les moy...     3   P2925  C10778
# ...

# %%
time parse_content_pers(sample)
# Out:
# CPU times: user 36.6 s, sys: 468 ms, total: 37.1 s
# Wall time: 9.57 s
#        page                  unittitle  \
# 14350    63                      Féret
# 34013   217  Fulminant, le vaisseau le
# 1580    141                    Massiot
# 23402   122             Lamorlière, de
# 12155    38                    Dalesme
# ...     ...                        ...
# 16105    17                     Bénard
# 32652   231    Renommée, la frégate la
# 26783   153         Mesnard du Plessis
# 14594   155                      Véron
# 7260     29                  Carmeline
#
#                                                  contenu  tome      ID  \
# 14350  Arrêté. Le prévôt de la Marine instruira son p...     3   P4471
# 34013                                       Le radouber.     2    B238
# 1580                          Commissaire à La Rochelle.     2   P7462
# 23402  cadet dans les troupes de Cayenne, sera passag...     8   P6171
# ...

# %%
sample = sample[sample['persname'].apply(lambda x : len(x)!=0)].copy()

# %%
sample
# Out:
#        page                                  unittitle  \
# 26859   228                          Petitpas, Isidore
# 42102   214                        Officiers de Marine
# 37696    60    Lettres ministérielles, 27 octobre 1691
# 28435    28                                   Bonneau
# 17602    12                          Barailh, sieur de
# 38956    78       Lettres ministérielles, 27 mars 1694
# 12813     2                                   Amariton
# 9042    281                                    Martrou
# 21606    15                                     Belamy
# 26681   163                           Lafaure, Raymond
# 7046    194                                     Vallet
# 3999    135                                       Huot
# 21822    65                Couture, Jean, dit La Fumée
# 634     210                        Saint-Estève, M. de
# 42763   332                   Médecine navale, hôpital
# 24904    51             Charuau, J. Louis [Jean-Louis]
# ...
